# %%
# Install spaCy 
# !pip install spacy

# Download spaCy English language model
# !python -m spacy download en_core_web_sm

import os
import spacy
import pandas as pd

# Load spaCy English language model
nlp = spacy.load("en_core_web_sm")

# Define the path to the directory containing song lyrics files
data_path = r"C:/Users/dudud/collecting data/lyrics/Midnights_TheTillDawnEdition_"
# Out:
# Requirement already satisfied: spacy in d:\software-d\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\software-d\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\software-d\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\software-d\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\software-d\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\software-d\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in d:\software-d\anaconda3\lib\site-packages (from spacy) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\software-d\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\software-d\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\software-d\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in d:\software-d\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in d:\software-d\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\software-d\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\software-d\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\software-d\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\software-d\anaconda3\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: jinja2 in d:\software-d\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in d:\software-d\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in d:\software-d\anaconda3\lib\site-packages (from spacy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\software-d\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in d:\software-d\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\software-d\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in d:\software-d\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\software-d\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software-d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\software-d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software-d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software-d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\software-d\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\software-d\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: colorama in d:\software-d\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\software-d\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in d:\software-d\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 
#      ------------------------------------- -- 12.1/12.8 MB 2.3 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 2.3 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 2.3 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 2.3 MB/s eta 0:00:01
#      -------------------------------------- - 12.4/12.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  12.5/12.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  12.5/12.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in d:\software-d\anaconda3\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.2)
# Requirement already satisfied: jinja2 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in d:\software-d\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\software-d\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in d:\software-d\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\software-d\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software-d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\software-d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software-d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software-d\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\software-d\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\software-d\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in d:\software-d\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\software-d\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in d:\software-d\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\software-d\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Initialize lists to store data for CSV
filenames = []
titles = []
documents = []
tokens_list = []
lemmas_list = []
pos_list = []

# Function to process and annotate a lyric file
def process_lyric_file(file_path):
    # Extract information from the file path
    filename = os.path.basename(file_path)
    song_title = os.path.splitext(filename)[0]  # Remove the file extension
    
    # Read the content of the file
    with open(file_path, "r", encoding="utf-8") as file:
        lyric_text = file.read()

    # Process the text using spaCy
    doc = nlp(lyric_text)
    
    # Extract tokens, lemmas, and parts of speech
    tokens = [token.text for token in doc]
    lemmas = [token.lemma_ for token in doc]
    pos = [token.pos_ for token in doc]

    # Append data to lists
    filenames.append(filename)
    titles.append(song_title)
    documents.append(lyric_text)
    tokens_list.append(tokens)
    lemmas_list.append(lemmas)
    pos_list.append(pos)

# Iterate through each file in the dataset folder
for file_name in os.listdir(data_path):
    if file_name.endswith(".txt"):  
        file_path = os.path.join(data_path, file_name)
        process_lyric_file(file_path)

# Create a DataFrame to store the data
data = {
    "Filename": filenames,
    "Title": titles,
    "Document": documents,
    "Tokens": tokens_list,
    "Lemmas": lemmas_list,
    "Parts-of-speech": pos_list,
}

df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
csv_path = "C:/Users/dudud/collecting data/lyrics/annotated_corpus.csv"
df.to_csv(csv_path, index=False)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                     Filename                  Title  \
# 0              Anti_Hero.txt              Anti_Hero
# 1              Bejeweled.txt              Bejeweled
# 2  BiggerThanTheWholeSky.txt  BiggerThanTheWholeSky
# 3             DearReader.txt             DearReader
# 4                 Glitch.txt                 Glitch
#
#                                             Document  \
# 0  Anti-Hero Lyrics[Verse 1]\nI have this thing w...
# 1  Bejeweled Lyrics[Verse 1]\nBaby love, I think ...
# 2  Bigger Than The Whole Sky Lyrics[Verse 1]\nNo ...
# 3  Dear Reader Lyrics[Verse 1]\nDear reader, if i...
# 4  Glitch Lyrics[Verse 1]\nWe were supposed to be...
#
#                                               Tokens  \
# 0  [Anti, -, Hero, Lyrics[Verse, 1, ], \n, I, hav...
# 1  [Bejeweled, Lyrics[Verse, 1, ], \n, Baby, love...
# 2  [Bigger, Than, The, Whole, Sky, Lyrics[Verse, ...
# 3  [Dear, Reader, Lyrics[Verse, 1, ], \n, Dear, r...
# 4  [Glitch, Lyrics[Verse, 1, ], \n, We, were, sup...
#
#                                               Lemmas  \
# 0  [Anti, -, Hero, lyrics[verse, 1, ], \n, I, hav...
# 1  [bejewel, lyrics[verse, 1, ], \n, Baby, love, ...
# 2  [big, than, the, Whole, Sky, lyrics[verse, 1, ...
# 3  [Dear, Reader, lyrics[verse, 1, ], \n, dear, r...
# 4  [glitch, lyrics[verse, 1, ], \n, we, be, suppo...
#
#                                      Parts-of-speech
# 0  [PROPN, PROPN, PROPN, NOUN, X, PUNCT, SPACE, P...
# 1  [VERB, NOUN, X, PUNCT, SPACE, PROPN, NOUN, PUN...
# 2  [ADJ, ADP, DET, PROPN, PROPN, NOUN, AUX, PUNCT...
# 3  [PROPN, PROPN, NOUN, X, PUNCT, SPACE, ADJ, NOU...
# 4  [VERB, NOUN, X, PUNCT, SPACE, PRON, AUX, VERB,...
